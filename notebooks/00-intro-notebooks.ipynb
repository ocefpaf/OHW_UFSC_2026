# %% [markdown]
# Objetivos:
#
# 1. Entender o que é uma célula de código.
# 1. Criar células de Markdown de suporte ao código e narrativa.
# 1. Importar bibliotecas.
# 1. Ler dados nos formatos mais comuns.
# 1. Obter dados online e gerar figuras.
